# %% [markdown]
# # Project 1
# ### Epidemiological Study: US Vaccination Campaign (November 2020 - March 2021)
# ---
# ### Project Description/Outline
# Determine the effectiveness of the US vaccination campaign in attending the population that is most affected by covid-19 disease. This is achieved by revising the total number of doses applied, vaccination coverage, population demographics such as gender, race, socioeconomic status, and education, versus epidemiologic variables: incidence, prevalence, hospitalization, UCI, death numbers.

# %%
## Dependencies
import pandas as pd
import requests
import time
import datetime
import matplotlib.pyplot as plt

# Import API key
from app_tokens import cdc_token

# %% [markdown]
# ### Covid-19 Vaccination Data

# %%
## Import data from CSV
hesitancy_df = pd.read_csv('data/Vaccine_Hesitancy_Covid19.csv')#, encoding='latin-1')
hesitancy_df.head()
# Out:
#    FIPS Code                 County Name    State  Estimated hesitant  \
# 0       1123  Tallapoosa County, Alabama  ALABAMA                0.23
# 1       1121   Talladega County, Alabama  ALABAMA                0.23
# 2       1131      Wilcox County, Alabama  ALABAMA                0.23
# 3       1129  Washington County, Alabama  ALABAMA                0.23
# 4       1133     Winston County, Alabama  ALABAMA                0.22
#
#    Estimated strongly hesitant  Social Vulnerability Index (SVI)  \
# 0                         0.12                              0.89
# 1                         0.11                              0.87
# 2                         0.11                              0.93
# 3                         0.11                              0.73
# 4                         0.11                              0.70
#
#               SVI Category  Ability to handle a COVID-19 outbreak (CVAC)  \
# 0  Very High Vulnerability                                          0.64
# 1  Very High Vulnerability                                          0.84
# 2  Very High Vulnerability                                          0.94
# 3       High Vulnerability                                          0.82
# 4       High Vulnerability                                          0.80
#
#              CVAC Category  Percent adults fully vaccinated against COVID-19  \
# 0       High Vulnerability                                             0.161
# 1  Very High Vulnerability                                             0.133
# 2  Very High Vulnerability                                             0.228
# 3  Very High Vulnerability                                             0.192
# 4       High Vulnerability                                             0.085
#
#    Percent Hispanic  Percent non-Hispanic American Indian/Alaska Native  \
# 0            0.0242                                             0.0022
# 1            0.0229                                             0.0043
# 2            0.0053                                             0.0009
# 3            0.0146                                             0.0731
# 4            0.0315                                             0.0034
#
#    Percent non-Hispanic Asian  Percent non-Hispanic Black  \
# 0                      0.0036                      0.2697
# 1                      0.0061                      0.3237
# 2                      0.0003                      0.6938
# 3                      0.0025                      0.2354
# 4                      0.0016                      0.0073
#
#    Percent non-Hispanic Native Hawaiian/Pacific Islander  \
# 0                                             0.0000
# 1                                             0.0003
# 2                                             0.0000
# 3                                             0.0000
# 4                                             0.0005
#
#    Percent non-Hispanic White            Geographical Point State Code  \
# 0                      0.6887  POINT (-86.844516 32.756889)         AL
# 1                      0.6263  POINT (-86.844516 32.756889)         AL
# 2                      0.2684  POINT (-86.844516 32.756889)         AL
# 3                      0.6495  POINT (-86.844516 32.756889)         AL
# 4                      0.9370  POINT (-86.844516 32.756889)         AL
#
#                                      County Boundary  \
# 0  MULTIPOLYGON (((-85.841259 33.104456, -85.8409...
# 1  MULTIPOLYGON (((-86.303069 33.46316, -86.30306...
# 2  MULTIPOLYGON (((-87.52534299999999 32.132773, ...
# 3  MULTIPOLYGON (((-88.45317899999999 31.505388, ...
# 4  MULTIPOLYGON (((-87.63656399999999 34.120908, ...
#
#                                       State Boundary
# 0  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 1  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 2  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 3  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 4  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...

# %% [markdown]
# ### Pendiente
# - Retrieve lat,lng as columns by fips
# - "POINT (-86.844516 32.756889)	"
# - separate

# %%
columns = [
    'FIPS Code',
    'Geographical Point',
    'Social Vulnerability Index (SVI)',
    'SVI Category',
    'Percent adults fully vaccinated against COVID-19',
    'Percent Hispanic',
    'Percent non-Hispanic American Indian/Alaska Native',
    'Percent non-Hispanic Asian',
    'Percent non-Hispanic Black',
    'Percent non-Hispanic Native Hawaiian/Pacific Islander',
    'Percent non-Hispanic White'
]

vaccination_df = hesitancy_df[columns].sort_values('FIPS Code')
vaccination_df.reset_index(inplace=True, drop=True)

vaccination_df['Percent non-Hispanic Other'] = 1 - vaccination_df.iloc[:,4:10].sum(axis=1)

vaccination_df.set_index('FIPS Code', drop=True, inplace=True)
vaccination_df.head()

# del hesitancy_df
# Out:
#                      Geographical Point  Social Vulnerability Index (SVI)  \
# FIPS Code
# 1001       POINT (-86.844516 32.756889)                              0.44
# 1003       POINT (-86.844516 32.756889)                              0.22
# 1005       POINT (-86.844516 32.756889)                              1.00
# 1007       POINT (-86.844516 32.756889)                              0.60
# 1009       POINT (-86.844516 32.756889)                              0.42
#
#                       SVI Category  \
# FIPS Code
# 1001        Moderate Vulnerability
# 1003             Low Vulnerability
# 1005       Very High Vulnerability
# 1007            High Vulnerability
# 1009        Moderate Vulnerability
#
#            Percent adults fully vaccinated against COVID-19  Percent Hispanic  \
# FIPS Code
# 1001                                                  0.114            0.0283
# 1003                                                  0.176            0.0456
# 1005                                                  0.128            0.0436
# 1007                                                  0.115            0.0257
# 1009                                                  0.095            0.0926
#
#            Percent non-Hispanic American Indian/Alaska Native  \
# FIPS Code
# 1001                                                  0.0025
# 1003                                                  0.0065
# 1005                                                  0.0029
# 1007                                                  0.0013
# 1009                                                  0.0007
#
#            Percent non-Hispanic Asian  Percent non-Hispanic Black  \
# FIPS Code
# 1001                           0.0103                      0.1900
# 1003                           0.0092                      0.0917
# 1005                           0.0048                      0.4744
# 1007                           0.0012                      0.2214
# 1009                           0.0037                      0.0153
#
#            Percent non-Hispanic Native Hawaiian/Pacific Islander  \
# FIPS Code
# 1001                                                  0.0001
# 1003                                                  0.0000
# 1005                                                  0.0000
# 1007                                                  0.0000
# 1009                                                  0.0004
#
#            Percent non-Hispanic White  Percent non-Hispanic Other
# FIPS Code
# 1001                           0.7460                      0.6548
# 1003                           0.8307                      0.6710
# 1005                           0.4581                      0.3463
# 1007                           0.7453                      0.6354
# 1009                           0.8689                      0.7923

# %% [markdown]
# ### US Census Reference (2019)

# %%
census_df = pd.read_csv(('data/US_Census2019_totals.csv'), encoding='latin-1')
census_df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2019  \
# 0        4779736            4780125          4785437  ...          1.917501
# 1          54571              54597            54773  ...          4.847310
# 2         182265             182265           183112  ...         24.017829
# 3          27457              27455            27327  ...         -5.690302
# 4          22915              22915            22870  ...          1.385134
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  \
# 0     0.578434     1.186314     1.522549     0.563489     0.626357
# 1     6.018182    -6.226119    -3.902226     1.970443    -1.712875
# 2    16.641870    17.488579    22.751474    20.184334    17.725964
# 3     0.292676    -6.897817    -8.132185    -5.140431   -15.724575
# 4    -4.998356    -3.787545    -5.797999     1.331144     1.329817
#
#    RNETMIG2016  RNETMIG2017  RNETMIG2018  RNETMIG2019
# 0     0.745172     1.090366     1.773786     2.483744
# 1     4.777171     0.849656     0.540916     4.560062
# 2    21.279291    22.398256    24.727215    24.380567
# 3   -18.238016   -24.998528    -8.754922    -5.165664
# 4    -0.708717    -3.234669    -6.857092     1.831952
#
# [5 rows x 164 columns]

# %%
census_2019 = census_df[['STATE', 'COUNTY', 'STNAME', 'CTYNAME', 'POPESTIMATE2019']]
census_2019.head()
# Out:
#    STATE  COUNTY   STNAME         CTYNAME  POPESTIMATE2019
# 0      1       0  Alabama         Alabama          4903185
# 1      1       1  Alabama  Autauga County            55869
# 2      1       3  Alabama  Baldwin County           223234
# 3      1       5  Alabama  Barbour County            24686
# 4      1       7  Alabama     Bibb County            22394

# %%
state_2019 = census_2019.loc[census_2019['COUNTY']==0]
state_2019.reset_index(inplace=True, drop=True)
# state_2019['POPESTIMATE2019'].sum()
state_2019
# Out:
#     STATE  COUNTY                STNAME               CTYNAME  POPESTIMATE2019
# 0       1       0               Alabama               Alabama          4903185
# 1       2       0                Alaska                Alaska           731545
# 2       4       0               Arizona               Arizona          7278717
# 3       5       0              Arkansas              Arkansas          3017804
# 4       6       0            California            California         39512223
# 5       8       0              Colorado              Colorado          5758736
# 6       9       0           Connecticut           Connecticut          3565287
# 7      10       0              Delaware              Delaware           973764
# 8      11       0  District of Columbia  District of Columbia           705749
# 9      12       0               Florida               Florida         21477737
# 10     13       0               Georgia               Georgia         10617423
# 11     15       0                Hawaii                Hawaii          1415872
# 12     16       0                 Idaho                 Idaho          1787065
# 13     17       0              Illinois              Illinois         12671821
# 14     18       0               Indiana               Indiana          6732219
# 15     19       0                  Iowa                  Iowa          3155070
# 16     20       0                Kansas                Kansas          2913314
# 17     21       0              Kentucky              Kentucky          4467673
# 18     22       0             Louisiana             Louisiana          4648794
# 19     23       0                 Maine                 Maine          1344212
# 20     24       0              Maryland              Maryland          6045680
# 21     25       0         Massachusetts         Massachusetts          6892503
# 22     26       0              Michigan              Michigan          9986857
# 23     27       0             Minnesota             Minnesota          5639632
# 24     28       0           Mississippi           Mississippi          2976149
# 25     29       0              Missouri              Missouri          6137428
# 26     30       0               Montana               Montana          1068778
# 27     31       0              Nebraska              Nebraska          1934408
# 28     32       0                Nevada                Nevada          3080156
# 29     33       0         New Hampshire         New Hampshire          1359711
# 30     34       0            New Jersey            New Jersey          8882190
# 31     35       0            New Mexico            New Mexico          2096829
# 32     36       0              New York              New York         19453561
# 33     37       0        North Carolina        North Carolina         10488084
# 34     38       0          North Dakota          North Dakota           762062
# 35     39       0                  Ohio                  Ohio         11689100
# 36     40       0              Oklahoma              Oklahoma          3956971
# 37     41       0                Oregon                Oregon          4217737
# 38     42       0          Pennsylvania          Pennsylvania         12801989
# 39     44       0          Rhode Island          Rhode Island          1059361
# 40     45       0        South Carolina        South Carolina          5148714
# 41     46       0          South Dakota          South Dakota           884659
# 42     47       0             Tennessee             Tennessee          6829174
# 43     48       0                 Texas                 Texas         28995881
# 44     49       0                  Utah                  Utah          3205958
# 45     50       0               Vermont               Vermont           623989
# 46     51       0              Virginia              Virginia          8535519
# 47     53       0            Washington            Washington          7614893
# 48     54       0         West Virginia         West Virginia          1792147
# 49     55       0             Wisconsin             Wisconsin          5822434
# 50     56       0               Wyoming               Wyoming           578759

# %%
county_2019 = census_2019.drop(census_2019.index[census_2019["COUNTY"]==0])
county_2019
# Out:
#       STATE  COUNTY   STNAME            CTYNAME  POPESTIMATE2019
# 1         1       1  Alabama     Autauga County            55869
# 2         1       3  Alabama     Baldwin County           223234
# 3         1       5  Alabama     Barbour County            24686
# 4         1       7  Alabama        Bibb County            22394
# 5         1       9  Alabama      Blount County            57826
# ...     ...     ...      ...                ...              ...
# 3188     56      37  Wyoming  Sweetwater County            42343
# 3189     56      39  Wyoming       Teton County            23464
# 3190     56      41  Wyoming       Uinta County            20226
# 3191     56      43  Wyoming    Washakie County             7805
# 3192     56      45  Wyoming      Weston County             6927
#
# [3142 rows x 5 columns]

# %%
fips = []
for index, row in  county_2019.iterrows():
    fips.append(f'{row["STATE"]:>02}{row["COUNTY"]:>03}')
    
county_2019.insert(0, 'FIPS Code', fips)
county_2019.drop(labels=['STATE', 'COUNTY'], axis=1, inplace=True)

# %%
county_2019
# Out:
#      FIPS Code   STNAME            CTYNAME  POPESTIMATE2019
# 1        01001  Alabama     Autauga County            55869
# 2        01003  Alabama     Baldwin County           223234
# 3        01005  Alabama     Barbour County            24686
# 4        01007  Alabama        Bibb County            22394
# 5        01009  Alabama      Blount County            57826
# ...        ...      ...                ...              ...
# 3188     56037  Wyoming  Sweetwater County            42343
# 3189     56039  Wyoming       Teton County            23464
# 3190     56041  Wyoming       Uinta County            20226
# 3191     56043  Wyoming    Washakie County             7805
# 3192     56045  Wyoming      Weston County             6927
#
# [3142 rows x 4 columns]

# %%
county_2019.shape
# Out:
# (3142, 4)

# %% [markdown]
# ### Pendiente
# - Agregar Male/Female
# - Agregar AgeGroup
# - Mover Ethnicity (desde Vaccination) en número / % ???

# %% [markdown]
# ### Nomenclatura AGEGRP de US Census a age_group

# %%
import numpy as np

all_data = pd.read_csv("data/cc-est2019-alldata.csv")#, encoding='latin-1')
all_data.head()
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50      1       1  Alabama  Autauga County     1       0    54571
# 1      50      1       1  Alabama  Autauga County     1       1     3579
# 2      50      1       1  Alabama  Autauga County     1       2     3991
# 3      50      1       1  Alabama  Autauga County     1       3     4290
# 4      50      1       1  Alabama  Autauga County     1       4     4290
#
#    TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# 0     26569       28002  ...        607          538         57           48
# 1      1866        1713  ...         77           56          9            5
# 2      2001        1990  ...         64           66          2            3
# 3      2171        2119  ...         51           57         13            7
# 4      2213        2077  ...         48           44          7            5
#
#    HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  HNAC_FEMALE
# 0         26           32          9           11         19           10
# 1          4            1          0            0          2            1
# 2          2            7          2            3          2            0
# 3          5            5          2            1          1            1
# 4          0            2          2            1          3            1
#
# [5 rows x 80 columns]

# %%
age_conditions = [
    (all_data['AGEGRP'] == 0),
    (all_data['AGEGRP'] >= 1) & (all_data['AGEGRP'] <= 4),
    (all_data['AGEGRP'] >= 5) & (all_data['AGEGRP'] <= 10),
    (all_data['AGEGRP'] >= 11) & (all_data['AGEGRP'] <= 13),
    (all_data['AGEGRP'] >= 14) & (all_data['AGEGRP'] <= 18) 
]

age_values = ['0', '0 - 17 years', '18 - 49 years', '50 - 64 years', '65 + years']

# %%
all_data['Age_group'] = np.select(age_conditions, age_values)
all_data.head()
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50      1       1  Alabama  Autauga County     1       0    54571
# 1      50      1       1  Alabama  Autauga County     1       1     3579
# 2      50      1       1  Alabama  Autauga County     1       2     3991
# 3      50      1       1  Alabama  Autauga County     1       3     4290
# 4      50      1       1  Alabama  Autauga County     1       4     4290
#
#    TOT_MALE  TOT_FEMALE  ...  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  HIAC_MALE  \
# 0     26569       28002  ...          538         57           48         26
# 1      1866        1713  ...           56          9            5          4
# 2      2001        1990  ...           66          2            3          2
# 3      2171        2119  ...           57         13            7          5
# 4      2213        2077  ...           44          7            5          0
#
#    HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  HNAC_FEMALE     Age_group
# 0           32          9           11         19           10             0
# 1            1          0            0          2            1  0 - 17 years
# 2            7          2            3          2            0  0 - 17 years
# 3            5          2            1          1            1  0 - 17 years
# 4            2          2            1          3            1  0 - 17 years
#
# [5 rows x 81 columns]

# %%
all_data_tot = all_data.loc[all_data['AGEGRP']==0]

# %%
all_data_tot = all_data_tot.loc[all_data['YEAR']==12]
all_data_tot.reset_index(inplace=True, drop=True)

# %%
fips_all_data = []
for index, row in  all_data_tot.iterrows():
    fips_all_data.append(f'{row["STATE"]:>02}{row["COUNTY"]:>03}')
    
all_data_tot.insert(0, 'FIPS Code', fips_all_data)
all_data_tot.drop(labels=['STATE', 'COUNTY'], axis=1, inplace=True)

# %%
all_data_tot
# Out:
#      FIPS Code  SUMLEV   STNAME            CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0        01001      50  Alabama     Autauga County    12       0    55869
# 1        01003      50  Alabama     Baldwin County    12       0   223234
# 2        01005      50  Alabama     Barbour County    12       0    24686
# 3        01007      50  Alabama        Bibb County    12       0    22394
# 4        01009      50  Alabama      Blount County    12       0    57826
# ...        ...     ...      ...                ...   ...     ...      ...
# 3137     56037      50  Wyoming  Sweetwater County    12       0    42343
# 3138     56039      50  Wyoming       Teton County    12       0    23464
# 3139     56041      50  Wyoming       Uinta County    12       0    20226
# 3140     56043      50  Wyoming    Washakie County    12       0     7805
# 3141     56045      50  Wyoming      Weston County    12       0     6927
#
#       TOT_MALE  TOT_FEMALE  WA_MALE  ...  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# 0        27092       28777    20878  ...          687         89           93
# 1       108247      114987    94810  ...         4646        268          281
# 2        13064       11622     6389  ...          408         63           50
# 3        11929       10465     8766  ...          253         32           19
# 4        28472       29354    27258  ...         2516         76           58
# ...        ...         ...      ...  ...          ...        ...          ...
# 3137     21808       20535    20446  ...         2997         83           73
# 3138     12142       11322    11567  ...         1578         25           23
# 3139     10224       10002     9753  ...          840         17           23
# 3140      3963        3842     3759  ...          489          7            9
# 3141      3624        3303     3392  ...          120          5            8
#
#       HIAC_MALE  HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  HNAC_FEMALE  \
# 0            40           27         15           19         16           11
# 1           264          197         69           65         55           35
# 2            61           26          1            0         14            8
# 3             6           15          5            1         17            3
# 4            67           66         18           21         34           21
# ...         ...          ...        ...          ...        ...          ...
# 3137        212          196         33           36         16            9
# 3138        105           81         16           15         12            7
# 3139         82          111          3           12          8            2
# 3140         54           59          7            8          4            2
# 3141         23           20          6            4          2            0
#
#       Age_group
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 3137          0
# 3138          0
# 3139          0
# 3140          0
# 3141          0
#
# [3142 rows x 80 columns]

# %%
county_2019.reset_index(inplace=True, drop=True)
county_2019.set_index('FIPS Code',drop=True, inplace=True)

# %%
county_2019
# Out:
#             STNAME            CTYNAME  POPESTIMATE2019
# FIPS Code
# 01001      Alabama     Autauga County            55869
# 01003      Alabama     Baldwin County           223234
# 01005      Alabama     Barbour County            24686
# 01007      Alabama        Bibb County            22394
# 01009      Alabama      Blount County            57826
# ...            ...                ...              ...
# 56037      Wyoming  Sweetwater County            42343
# 56039      Wyoming       Teton County            23464
# 56041      Wyoming       Uinta County            20226
# 56043      Wyoming    Washakie County             7805
# 56045      Wyoming      Weston County             6927
#
# [3142 rows x 3 columns]

# %%
gender_tot_sub = all_data_tot[['FIPS Code', 'TOT_MALE','TOT_FEMALE']]
gender_tot_sub
# Out:
#      FIPS Code  TOT_MALE  TOT_FEMALE
# 0        01001     27092       28777
# 1        01003    108247      114987
# 2        01005     13064       11622
# 3        01007     11929       10465
# 4        01009     28472       29354
# ...        ...       ...         ...
# 3137     56037     21808       20535
# 3138     56039     12142       11322
# 3139     56041     10224       10002
# 3140     56043      3963        3842
# 3141     56045      3624        3303
#
# [3142 rows x 3 columns]

# %%
census_2019_sex = gender_tot_sub.set_index('FIPS Code', drop=True)

# %%
# county_2019 = county_2019.merge(gender_tot_sub, on='FIPS Code', how='outer')
# county_2019
# Out:
#      FIPS Code   STNAME            CTYNAME  POPESTIMATE2019  TOT_MALE  \
# 0        01001  Alabama     Autauga County            55869     27092
# 1        01003  Alabama     Baldwin County           223234    108247
# 2        01005  Alabama     Barbour County            24686     13064
# 3        01007  Alabama        Bibb County            22394     11929
# 4        01009  Alabama      Blount County            57826     28472
# ...        ...      ...                ...              ...       ...
# 3137     56037  Wyoming  Sweetwater County            42343     21808
# 3138     56039  Wyoming       Teton County            23464     12142
# 3139     56041  Wyoming       Uinta County            20226     10224
# 3140     56043  Wyoming    Washakie County             7805      3963
# 3141     56045  Wyoming      Weston County             6927      3624
#
#       TOT_FEMALE
# 0          28777
# 1         114987
# 2          11622
# 3          10465
# 4          29354
# ...          ...
# 3137       20535
# 3138       11322
# 3139       10002
# 3140        3842
# 3141        3303
#
# [3142 rows x 6 columns]

# %% [markdown]
# ###### County_2019 dataframe with age group totals

# %%
all_data_age = all_data[['STATE', 'COUNTY', 'YEAR', 'TOT_POP', 'Age_group']]
all_data_age
# Out:
#         STATE  COUNTY  YEAR  TOT_POP     Age_group
# 0           1       1     1    54571             0
# 1           1       1     1     3579  0 - 17 years
# 2           1       1     1     3991  0 - 17 years
# 3           1       1     1     4290  0 - 17 years
# 4           1       1     1     4290  0 - 17 years
# ...       ...     ...   ...      ...           ...
# 716371     56      45    12      499    65 + years
# 716372     56      45    12      352    65 + years
# 716373     56      45    12      229    65 + years
# 716374     56      45    12      198    65 + years
# 716375     56      45    12      200    65 + years
#
# [716376 rows x 5 columns]

# %%
all_data_age = all_data_age.drop(all_data_age.index[all_data_age["Age_group"]=='0'])

# %%
all_data_age = all_data_age.loc[all_data_age['YEAR']==12]
all_data_age
# Out:
#         STATE  COUNTY  YEAR  TOT_POP      Age_group
# 210         1       1    12     3277   0 - 17 years
# 211         1       1    12     3465   0 - 17 years
# 212         1       1    12     3851   0 - 17 years
# 213         1       1    12     3659   0 - 17 years
# 214         1       1    12     3178  18 - 49 years
# ...       ...     ...   ...      ...            ...
# 716371     56      45    12      499     65 + years
# 716372     56      45    12      352     65 + years
# 716373     56      45    12      229     65 + years
# 716374     56      45    12      198     65 + years
# 716375     56      45    12      200     65 + years
#
# [56556 rows x 5 columns]

# %%
fips_age = []
for index, row in  all_data_age.iterrows():
    fips_age.append(f'{row["STATE"]:>02}{row["COUNTY"]:>03}')
    
all_data_age.insert(0, 'FIPS Code', fips_age)
all_data_age.drop(labels=['STATE', 'COUNTY'], axis=1, inplace=True)

# %%
all_data_age
# Out:
#        FIPS Code  YEAR  TOT_POP      Age_group
# 210        01001    12     3277   0 - 17 years
# 211        01001    12     3465   0 - 17 years
# 212        01001    12     3851   0 - 17 years
# 213        01001    12     3659   0 - 17 years
# 214        01001    12     3178  18 - 49 years
# ...          ...   ...      ...            ...
# 716371     56045    12      499     65 + years
# 716372     56045    12      352     65 + years
# 716373     56045    12      229     65 + years
# 716374     56045    12      198     65 + years
# 716375     56045    12      200     65 + years
#
# [56556 rows x 4 columns]

# %%
age_group = pd.DataFrame(all_data_age.groupby(['FIPS Code','Age_group'])['TOT_POP'].sum())

# %%
census_2019_age = age_group.unstack()

# %%
county_2019
# Out:
#        STNAME            CTYNAME  POPESTIMATE2019  TOT_MALE  TOT_FEMALE
# 0     Alabama     Autauga County            55869     27092       28777
# 1     Alabama     Baldwin County           223234    108247      114987
# 2     Alabama     Barbour County            24686     13064       11622
# 3     Alabama        Bibb County            22394     11929       10465
# 4     Alabama      Blount County            57826     28472       29354
# ...       ...                ...              ...       ...         ...
# 3137  Wyoming  Sweetwater County            42343     21808       20535
# 3138  Wyoming       Teton County            23464     12142       11322
# 3139  Wyoming       Uinta County            20226     10224       10002
# 3140  Wyoming    Washakie County             7805      3963        3842
# 3141  Wyoming      Weston County             6927      3624        3303
#
# [3142 rows x 5 columns]

# %%
census_2019_ethnicity = vaccination_df[[
    'Percent Hispanic',
    'Percent non-Hispanic American Indian/Alaska Native',
    'Percent non-Hispanic Asian',
    'Percent non-Hispanic Black',
    'Percent non-Hispanic Native Hawaiian/Pacific Islander',
    'Percent non-Hispanic White',
    'Percent non-Hispanic Other'
]]
census_2019_ethnicity.reset_index(inplace=True)
type(f"{census_2019_ethnicity['FIPS Code'][0]}")
# Out:
# str

# %%
fips_ethnicity = []
for index, row in  census_2019_ethnicity.iterrows():
    row_string = f"{row['FIPS Code']:.0f}"
    fips_ethnicity.append(f"{row_string:>05}")

# %%
fips_ethnicity[0]
# Out:
# '01001'

# %%
census_2019_ethnicity.drop('FIPS Code', axis=1)
# Out:
#       Percent Hispanic  Percent non-Hispanic American Indian/Alaska Native  \
# 0               0.0283                                             0.0025
# 1               0.0456                                             0.0065
# 2               0.0436                                             0.0029
# 3               0.0257                                             0.0013
# 4               0.0926                                             0.0007
# ...                ...                                                ...
# 3137            0.1588                                             0.0102
# 3138            0.1503                                             0.0033
# 3139            0.0913                                             0.0065
# 3140            0.1423                                             0.0052
# 3141            0.0108                                             0.0017
#
#       Percent non-Hispanic Asian  Percent non-Hispanic Black  \
# 0                         0.0103                      0.1900
# 1                         0.0092                      0.0917
# 2                         0.0048                      0.4744
# 3                         0.0012                      0.2214
# 4                         0.0037                      0.0153
# ...                          ...                         ...
# 3137                      0.0074                      0.0112
# 3138                      0.0125                      0.0124
# 3139                      0.0016                      0.0011
# 3140                      0.0000                      0.0004
# 3141                      0.0077                      0.0023
#
#       Percent non-Hispanic Native Hawaiian/Pacific Islander  \
# 0                                                0.0001
# 1                                                0.0000
# 2                                                0.0000
# 3                                                0.0000
# 4                                                0.0004
# ...                                                 ...
# 3137                                             0.0003
# 3138                                             0.0012
# 3139                                             0.0000
# 3140                                             0.0000
# 3141                                             0.0011
#
#       Percent non-Hispanic White  Percent non-Hispanic Other
# 0                         0.7460                      0.6548
# 1                         0.8307                      0.6710
# 2                         0.4581                      0.3463
# 3                         0.7453                      0.6354
# 4                         0.8689                      0.7923
# ...                          ...                         ...
# 3137                      0.7956                      0.5841
# 3138                      0.8134                      0.5153
# 3139                      0.8752                      0.6935
# 3140                      0.8190                      0.5881
# 3141                      0.9637                      0.7604
#
# [3142 rows x 7 columns]

# %%
census_2019_ethnicity
# Out:
#      FIPS Code  Percent Hispanic  \
# 0        01001            0.0283
# 1        01003            0.0456
# 2        01005            0.0436
# 3        01007            0.0257
# 4        01009            0.0926
# ...        ...               ...
# 3137     56037            0.1588
# 3138     56039            0.1503
# 3139     56041            0.0913
# 3140     56043            0.1423
# 3141     56045            0.0108
#
#       Percent non-Hispanic American Indian/Alaska Native  \
# 0                                                0.0025
# 1                                                0.0065
# 2                                                0.0029
# 3                                                0.0013
# 4                                                0.0007
# ...                                                 ...
# 3137                                             0.0102
# 3138                                             0.0033
# 3139                                             0.0065
# 3140                                             0.0052
# 3141                                             0.0017
#
#       Percent non-Hispanic Asian  Percent non-Hispanic Black  \
# 0                         0.0103                      0.1900
# 1                         0.0092                      0.0917
# 2                         0.0048                      0.4744
# 3                         0.0012                      0.2214
# 4                         0.0037                      0.0153
# ...                          ...                         ...
# 3137                      0.0074                      0.0112
# 3138                      0.0125                      0.0124
# 3139                      0.0016                      0.0011
# 3140                      0.0000                      0.0004
# 3141                      0.0077                      0.0023
#
#       Percent non-Hispanic Native Hawaiian/Pacific Islander  \
# 0                                                0.0001
# 1                                                0.0000
# 2                                                0.0000
# 3                                                0.0000
# 4                                                0.0004
# ...                                                 ...
# 3137                                             0.0003
# 3138                                             0.0012
# 3139                                             0.0000
# 3140                                             0.0000
# 3141                                             0.0011
#
#       Percent non-Hispanic White  Percent non-Hispanic Other
# 0                         0.7460                      0.6548
# 1                         0.8307                      0.6710
# 2                         0.4581                      0.3463
# 3                         0.7453                      0.6354
# 4                         0.8689                      0.7923
# ...                          ...                         ...
# 3137                      0.7956                      0.5841
# 3138                      0.8134                      0.5153
# 3139                      0.8752                      0.6935
# 3140                      0.8190                      0.5881
# 3141                      0.9637                      0.7604
#
# [3142 rows x 8 columns]

# %%
census_2019_combined = county_2019
census_2019_combined = census_2019_combined.merge(census_2019_sex, how='inner', left_index=True, right_index=True)
census_2019_combined = census_2019_combined.merge(census_2019_age['TOT_POP'], how='inner', left_index=True, right_index=True)

# %%
census_2019_combined = census_2019_combined.merge(census_2019_ethnicity, how='inner', left_index=True, right_index=True)

# %%
census_2019_combined
# Out:
#             STNAME            CTYNAME  POPESTIMATE2019  TOT_MALE  TOT_FEMALE  \
# FIPS Code
# 01001      Alabama     Autauga County            55869     27092       28777
# 01003      Alabama     Baldwin County           223234    108247      114987
# 01005      Alabama     Barbour County            24686     13064       11622
# 01007      Alabama        Bibb County            22394     11929       10465
# 01009      Alabama      Blount County            57826     28472       29354
# ...            ...                ...              ...       ...         ...
# 56037      Wyoming  Sweetwater County            42343     21808       20535
# 56039      Wyoming       Teton County            23464     12142       11322
# 56041      Wyoming       Uinta County            20226     10224       10002
# 56043      Wyoming    Washakie County             7805      3963        3842
# 56045      Wyoming      Weston County             6927      3624        3303
#
#            0 - 17 years  18 - 49 years  50 - 64 years  65 + years
# FIPS Code
# 01001             14252          21652          11041        8924
# 01003             52268          77402          46734       46830
# 01005              5595           9477           4753        4861
# 01007              4992           9233           4436        3733
# 01009             14522          21002          11488       10814
# ...                 ...            ...            ...         ...
# 56037             12049          16959           7846        5489
# 56039              4586          10694           4467        3717
# 56041              6215           7229           3757        3025
# 56043              1960           2506           1609        1730
# 56045              1529           2362           1558        1478
#
# [3142 rows x 9 columns]

# %%
geo_points = vaccination_df['Geographical Point']
# Out:
# FIPS Code
# 1001     POINT (-86.844516 32.756889)
# 1003     POINT (-86.844516 32.756889)
# 1005     POINT (-86.844516 32.756889)
# 1007     POINT (-86.844516 32.756889)
# 1009     POINT (-86.844516 32.756889)
#                      ...
# 56037    POINT (-107.55145 42.999627)
# 56039    POINT (-107.55145 42.999627)
# 56041    POINT (-107.55145 42.999627)
# 56043    POINT (-107.55145 42.999627)
# 56045    POINT (-107.55145 42.999627)
# Name: Geographical Point, Length: 3142, dtype: object

# %%
geo_points[1001]
# Out:
# 'POINT (-86.844516 32.756889)'

# %%
test = geo_points[1001].split(' ')
lat=test[2]
lng=test[1]
print(lat,lng)
# Out:
# 32.756889) (-86.844516

# %%
lng[1:len(lng)]
# Out:
# '-86.844516'

# %%
# points = [geo_points[1001]]
lat = []
lng = []

for point in geo_points:
     (a, b, c) = point.split(' ')
     lat.append(c[0:len(c)-1])
     lng.append(b[1:len(b)])

# %%
len(lat)
# Out:
# 3142

# %%
len(lng)
# Out:
# 3142

# %%
census_2019_combined['Latitude'] = lat
census_2019_combined['Longitude'] = lng

# %%
census_2019_combined
# Out:
#             STNAME            CTYNAME  POPESTIMATE2019  TOT_MALE  TOT_FEMALE  \
# FIPS Code
# 01001      Alabama     Autauga County            55869     27092       28777
# 01003      Alabama     Baldwin County           223234    108247      114987
# 01005      Alabama     Barbour County            24686     13064       11622
# 01007      Alabama        Bibb County            22394     11929       10465
# 01009      Alabama      Blount County            57826     28472       29354
# ...            ...                ...              ...       ...         ...
# 56037      Wyoming  Sweetwater County            42343     21808       20535
# 56039      Wyoming       Teton County            23464     12142       11322
# 56041      Wyoming       Uinta County            20226     10224       10002
# 56043      Wyoming    Washakie County             7805      3963        3842
# 56045      Wyoming      Weston County             6927      3624        3303
#
#            0 - 17 years  18 - 49 years  50 - 64 years  65 + years   Latitude  \
# FIPS Code
# 01001             14252          21652          11041        8924  32.756889
# 01003             52268          77402          46734       46830  32.756889
# 01005              5595           9477           4753        4861  32.756889
# 01007              4992           9233           4436        3733  32.756889
# 01009             14522          21002          11488       10814  32.756889
# ...                 ...            ...            ...         ...        ...
# 56037             12049          16959           7846        5489  42.999627
# 56039              4586          10694           4467        3717  42.999627
# 56041              6215           7229           3757        3025  42.999627
# 56043              1960           2506           1609        1730  42.999627
# 56045              1529           2362           1558        1478  42.999627
#
#             Longitude
# FIPS Code
# 01001      -86.844516
# 01003      -86.844516
# 01005      -86.844516
# 01007      -86.844516
# 01009      -86.844516
# ...               ...
# 56037      -107.55145
# 56039      -107.55145
# 56041      -107.55145
# 56043      -107.55145
# 56045      -107.55145
#
# [3142 rows x 11 columns]

# %%
census_2019_combined.to_csv('analysis_data/census_2019.csv')

# %% [markdown]
# ### Covid-19 Case Surveillance

# %%
months = ['2020-01', '2020-02', '2020-03', '2020-04', '2020-05',
          '2020-06', '2020-07', '2020-08', '2020-09', '2020-10',
          '2020-11', '2020-12', '2021-01', '2021-02', '2021-03']

# fields = 'case_month, county_fips_code, current_status, sex, age_group, race, ethnicity, hosp_yn, icu_yn, death_yn'
fields = 'case_month, county_fips_code, hosp_yn, icu_yn, death_yn'
fips.append('NA')

patients_df = pd.DataFrame(index=fips)
hospitalized_df = pd.DataFrame(index=fips)
icu_df = pd.DataFrame(index=fips)
death_df = pd.DataFrame(index=fips)

patients_df.index.rename('FIPS Code', inplace=True)
hospitalized_df.index.rename('FIPS Code', inplace=True)
icu_df.index.rename('FIPS Code', inplace=True)
death_df.index.rename('FIPS Code', inplace=True)

# %%
query_url = "https://data.cdc.gov/resource/n8mc-b4w4.json?"
params = {
    '$$app_token': cdc_token,
    '$limit': 25000000,
    '$offset': 0,
    '$select': fields
}

# %%
months = ['2020-11']

## Print Log Header
print("Beginning Data Retrieval")
print("------------------------------")

## Retrieve Loop
for month in months:
    
    ## Print Log Status
    print(f"Processing Month: {month} [{datetime.datetime.now().strftime('%H:%M:%S')}]")
    
    ## Set month query
    params['case_month'] = month
    ## Retrieve month data & Store in DataFrame
    response_month = requests.get(query_url, params=params).json()
    response_df = pd.DataFrame(response_month)

    patients_df[month] = response_df.groupby('county_fips_code')['case_month'].count()
    hospitalized_df[month] = response_df.loc[response_df['hosp_yn'] == 'Yes'].groupby('county_fips_code')['hosp_yn'].count()
    icu_df[month] = response_df.loc[response_df['icu_yn'] == 'Yes'].groupby('county_fips_code')['icu_yn'].count()
    death_df[month] = response_df.loc[response_df['death_yn'] == 'Yes'].groupby('county_fips_code')['death_yn'].count()

    if month != months[-1]:
        print("Sleeping...")
        time.sleep(60*30)

## Print Log Footer
print("------------------------------")        
print("Data Retrieval Complete")
print("------------------------------")

# %%
patients_df

# %%
patients_df.fillna(0, inplace=True)
hospitalized_df.fillna(0, inplace=True)
icu_df.fillna(0, inplace=True)
death_df.fillna(0, inplace=True)

patients_df.to_csv('clean_data/patients.csv')
hospitalized_df.to_csv('clean_data/hospitalized.csv')
icu_df.to_csv('clean_data/icu.csv')
death_df.to_csv('clean_data/death.csv')

# %%
patients_df.sum()

# %%
hospitalized_df.sum()

# %%
icu_df.sum()

# %%
death_df.sum()

# %% [markdown]
# ### Pendientes
#
# 1. Un DF con 18 meses (columnas) por: Deidentified Patients, Hosp_YN, ICU_YN, Death_YN
# 2. Al final, agregar suma de todos los meses
# 3. Un DF con todos los totales [patients, hosp, ]
# 4. Un DF con todos los totales [patients, hosp, ] (por c/100k hab)
#     (total*pop/100,000)
# 5. Agregar Columna  Vacunados en 4 y 5

# %% [markdown]
# ### Gráficas
#
# ...Peores fips por definir
#
# 1. Vacunados vs. tiempo (total/estado) + Pacientes vs. tiempo
# 2. Línea de tiempo (peores fips) vacunados vs afectados
# 3. Caracterizar (sexo, edad, etnicidad) a la media de los peores fips vs media mejores fips
# 4. Peores/Mejores fips: Avance vacunación (stacked bars)
# 5. Scatter (pacientes, vacunados) por fips
#     a. Pearson + LinRegress
# 6. Heatmap (vacunación vs. afectados)
# 7. Regresiones por sexo, edad, grupo étnico
# 8. Barras agrupadas por grupo étnico

# %% [markdown]
# ### Respaldo Mariana

# %%
import pandas as pd
import sqlalchemy
from sodapy import Socrata

socrata_domain = 'data.cdc.gov'
socrata_dataset_identifier = "n8mc-b4w4"

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata(socrata_domain, None)

#Get metadata
metadata = client.get_metadata(socrata_dataset_identifier)
[x['name'] for x in metadata['columns']]

# %%
results = client.get(socrata_dataset_identifier,limit = 24441351,
                      #where = "current_status"=="Laboratory-confirmed case",
                     select="county_fips_code,case_month,current_status,sex,age_group,race,ethnicity,hosp_yn,icu_yn,death_yn"
                    )
                    
tryout_df = pd.DataFrame.from_records(results)

# %%
tryout_df.head()

# %%
tryout_df['current_status'].value_counts()

# %%
url = https://data.cdc.gov/resource/n8mc-b4w4.json?case_month=2020-12&current_status=Laboratory-confirmed case
